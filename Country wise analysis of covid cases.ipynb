# %%
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.colors as mcolors
import pandas as pd 
import random
import math
import time
import numpy as np

# %%
confirmed_df = pd.read_csv("time_series_covid19_confirmed_global.csv")
confirmed_df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  07-04-2020  07-05-2020  \
# 0        0        0        0        0  ...       32672       32951
# 1        0        0        0        0  ...        2819        2893
# 2        0        0        0        0  ...       15500       15941
# 3        0        0        0        0  ...         855         855
# 4        0        0        0        0  ...         346         346
#
#    07-06-2020  07-07-2020  07-08-2020  07-09-2020  07-10-2020  07-11-2020  \
# 0       33190       33384       33594       33908       34194       34366
# 1        2964        3038        3106        3188        3278        3371
# 2       16404       16879       17348       17808       18242       18712
# 3         855         855         855         855         855         855
# 4         346         386         386         396         458         462
#
#    07-12-2020  7/13/20
# 0       34451    34455
# 1        3454     3571
# 2       19195    19689
# 3         855      858
# 4         506      525
#
# [5 rows x 178 columns]

# %%
recovered_df=pd.read_csv("time_series_covid19_recovered_global.csv")
recovered_df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  07-04-2020  07-05-2020  \
# 0        0        0        0        0  ...       19164       19366
# 1        0        0        0        0  ...        1637        1657
# 2        0        0        0        0  ...       11181       11492
# 3        0        0        0        0  ...         800         800
# 4        0        0        0        0  ...         108         108
#
#    07-06-2020  07-07-2020  07-08-2020  07-09-2020  07-10-2020  07-11-2020  \
# 0       20103       20179       20700       20847       20882       21135
# 1        1702        1744        1791        1832        1875        1881
# 2       11884       12094       12329       12637       13124       13124
# 3         800         800         802         802         803         803
# 4         108         117         117         117         117         118
#
#    07-12-2020  7/13/20
# 0       21216    21254
# 1        1946     2014
# 2       13743    14019
# 3         803      803
# 4         118      118
#
# [5 rows x 178 columns]

# %%
latest_data = pd.read_csv("csse_daily.csv")
latest_data.head()
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-07-13 04:43:04
# 1  22001.0     Acadia       Louisiana             US  2020-07-13 04:43:04
# 2  51001.0   Accomack        Virginia             US  2020-07-13 04:43:04
# 3  16001.0        Ada           Idaho             US  2020-07-13 04:43:04
# 4  19001.0      Adair            Iowa             US  2020-07-13 04:43:04
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707        153       1          0   152.0
# 1  30.295065  -92.414197       1339      45          0  1294.0
# 2  37.767072  -75.632346       1042      14          0  1028.0
# 3  43.452658 -116.241552       4146      25          0  4121.0
# 4  41.330756  -94.471059         17       0          0    17.0
#
#                     Combined_Key  Incidence_Rate  Case-Fatality_Ratio
# 0  Abbeville, South Carolina, US      623.802340             0.653595
# 1          Acadia, Louisiana, US     2158.111048             3.360717
# 2         Accomack, Virginia, US     3224.408962             1.343570
# 3                 Ada, Idaho, US      860.903637             0.602991
# 4                Adair, Iowa, US      237.695749             0.000000

# %%
latest_data.columns
# Out:
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incidence_Rate', 'Case-Fatality_Ratio'],
#       dtype='object')

# %%
unique_countries =  list(latest_data['Country_Region'].unique())

# %%
country_confirmed_cases = []
country_death_cases = [] 
country_active_cases = []
country_recovery_cases = []
country_mortality_rate = [] 


no_cases = []
for i in unique_countries:
    cases = latest_data[latest_data['Country_Region']==i]['Confirmed'].sum()
    if cases > 0:
        country_confirmed_cases.append(cases)
    else:
        no_cases.append(i)
        
for i in no_cases:
    unique_countries.remove(i)
    
# sort countries by the number of confirmed cases
unique_countries = [k for k, v in sorted(zip(unique_countries, country_confirmed_cases), key=operator.itemgetter(1), reverse=True)]
for i in range(len(unique_countries)):
    country_confirmed_cases[i] = latest_data[latest_data['Country_Region']==unique_countries[i]]['Confirmed'].sum()
    country_death_cases.append(latest_data[latest_data['Country_Region']==unique_countries[i]]['Deaths'].sum())
    country_recovery_cases.append(latest_data[latest_data['Country_Region']==unique_countries[i]]['Recovered'].sum())
    country_active_cases.append(country_confirmed_cases[i] - country_death_cases[i] - country_recovery_cases[i])
    country_mortality_rate.append(country_death_cases[i]/country_confirmed_cases[i])

# %%
country_df = pd.DataFrame({'Country Name': unique_countries, 'Number of Confirmed Cases': country_confirmed_cases,
                          'Number of Deaths': country_death_cases, 'Number of Recoveries' : country_recovery_cases, 
                          'Number of Active Cases' : country_active_cases,
                          'Mortality Rate': country_mortality_rate})
# number of cases per country/region

country_df.style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row0_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row0_col3 {
#             background-color:  #16803c;
#             color:  #f1f1f1;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row0_col4 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row0_col5 {
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row1_col1 {
#             background-color:  #5ab769;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row1_col2 {
#             background-color:  #66bd6f;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row1_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row1_col4 {
#             background-color:  #c9eac2;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row1_col5 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row2_col1 {
#             background-color:  #c2e7bb;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row2_col2 {
#             background-color:  #dbf1d5;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row2_col3 {
#             background-color:  #8ace88;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row2_col4 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row2_col5 {
#             background-color:  #eaf7e6;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row3_col1 {
#             background-color:  #ceecc8;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row3_col2 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row3_col3 {
#             background-color:  #99d595;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row3_col4 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row3_col5 {
#             background-color:  #eff9ec;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row4_col1 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row4_col2 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row4_col3 {
#             background-color:  #dbf1d5;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row4_col4 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row4_col5 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row5_col1 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row5_col2 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row5_col3 {
#             background-color:  #cdecc7;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row5_col4 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row5_col5 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row6_col1 {
#             background-color:  #eaf7e6;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row6_col2 {
#             background-color:  #c4e8bd;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row6_col3 {
#             background-color:  #d7efd1;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row6_col4 {
#             background-color:  #f5fbf3;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row6_col5 {
#             background-color:  #94d390;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row7_col1 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row7_col2 {
#             background-color:  #aedea7;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row7_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row7_col4 {
#             background-color:  #e7f6e3;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row7_col5 {
#             background-color:  #63bc6e;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row8_col1 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row8_col2 {
#             background-color:  #f3faf0;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row8_col3 {
#             background-color:  #e8f6e3;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row8_col4 {
#             background-color:  #eef8ea;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row8_col5 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row9_col1 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row9_col2 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row9_col3 {
#             background-color:  #daf0d4;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row9_col4 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row9_col5 {
#             background-color:  #daf0d4;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row10_col1 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row10_col2 {
#             background-color:  #d1edcb;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row10_col3 {
#             background-color:  #e6f5e1;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row10_col4 {
#             background-color:  #f2faf0;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row10_col5 {
#             background-color:  #9bd696;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row11_col1 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row11_col2 {
#             background-color:  #f2faef;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row11_col3 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row11_col4 {
#             background-color:  #f2faef;
#             color:  #000000;
#         }    #T_f1f3b234_d4c1_11ea_b31b_f0761c5f60a3row11_col5 {
#             background-color:  #edf8e9;
#             color:  #0

# %%
unique_provinces =  list(latest_data['Province_State'].unique())

# %%
province_confirmed_cases = []
province_country = [] 
province_death_cases = [] 
province_recovery_cases = []
province_mortality_rate = [] 

no_cases = [] 
for i in unique_provinces:
    cases = latest_data[latest_data['Province_State']==i]['Confirmed'].sum()
    if cases > 0:
        province_confirmed_cases.append(cases)
    else:
        no_cases.append(i)
 
# remove areas with no confirmed cases
for i in no_cases:
    unique_provinces.remove(i)
    
unique_provinces = [k for k, v in sorted(zip(unique_provinces, province_confirmed_cases), key=operator.itemgetter(1), reverse=True)]
for i in range(len(unique_provinces)):
    province_confirmed_cases[i] = latest_data[latest_data['Province_State']==unique_provinces[i]]['Confirmed'].sum()
    province_country.append(latest_data[latest_data['Province_State']==unique_provinces[i]]['Country_Region'].unique()[0])
    province_death_cases.append(latest_data[latest_data['Province_State']==unique_provinces[i]]['Deaths'].sum())
    province_recovery_cases.append(latest_data[latest_data['Province_State']==unique_provinces[i]]['Recovered'].sum())
    province_mortality_rate.append(province_death_cases[i]/province_confirmed_cases[i])

# %%
# number of cases per province/state/city
province_df = pd.DataFrame({'Province/State Name': unique_provinces, 'Country': province_country, 'Number of Confirmed Cases': province_confirmed_cases,
                          'Number of Deaths': province_death_cases, 'Number of Recoveries' : province_recovery_cases,
                          'Mortality Rate': province_mortality_rate})
# number of cases per country/region

province_df.style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row0_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row0_col3 {
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row0_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row0_col5 {
#             background-color:  #a4da9e;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row1_col2 {
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row1_col3 {
#             background-color:  #88ce87;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row1_col4 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row1_col5 {
#             background-color:  #cfecc9;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row2_col2 {
#             background-color:  #137d39;
#             color:  #f1f1f1;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row2_col3 {
#             background-color:  #daf0d4;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row2_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row2_col5 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row3_col2 {
#             background-color:  #369f54;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row3_col3 {
#             background-color:  #e8f6e4;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row3_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row3_col5 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row4_col2 {
#             background-color:  #3aa357;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row4_col3 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row4_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row4_col5 {
#             background-color:  #eff9ec;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row5_col2 {
#             background-color:  #3fa85b;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row5_col3 {
#             background-color:  #c6e8bf;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row5_col4 {
#             background-color:  #3fa85b;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row5_col5 {
#             background-color:  #d8f0d2;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row6_col2 {
#             background-color:  #42ab5d;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row6_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row6_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row6_col5 {
#             background-color:  #289049;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row7_col2 {
#             background-color:  #4eb264;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row7_col3 {
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row7_col4 {
#             background-color:  #00451c;
#             color:  #f1f1f1;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row7_col5 {
#             background-color:  #e7f6e3;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row8_col2 {
#             background-color:  #56b567;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row8_col3 {
#             background-color:  #e8f6e4;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row8_col4 {
#             background-color:  #248c46;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row8_col5 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row9_col2 {
#             background-color:  #8bcf89;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row9_col3 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row9_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row9_col5 {
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row10_col2 {
#             background-color:  #8bcf89;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row10_col3 {
#             background-color:  #9ed798;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row10_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row10_col5 {
#             background-color:  #98d594;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row11_col2 {
#             background-color:  #9ed798;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row11_col3 {
#             background-color:  #d7efd1;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row11_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row11_col5 {
#             background-color:  #cfecc9;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row12_col2 {
#             background-color:  #aadda4;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row12_col3 {
#             background-color:  #f0f9ed;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row12_col4 {
#             background-color:  #97d492;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row12_col5 {
#             background-color:  #eef8ea;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row13_col2 {
#             background-color:  #abdda5;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row13_col3 {
#             background-color:  #dbf1d5;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row13_col4 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row13_col5 {
#             background-color:  #ccebc6;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row14_col2 {
#             background-color:  #b1e0ab;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row14_col3 {
#             background-color:  #bde5b6;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row14_col4 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_f98fd8a6_d4c1_11ea_b28b_f0761c5f60a3row14_col5 {
#             background-color:  #99d595;

# %%
# Only show 10 countries with the most confirmed cases, the rest are grouped into the other category
visual_unique_countries = [] 
visual_confirmed_cases = []
others = np.sum(country_confirmed_cases[10:])

for i in range(len(country_confirmed_cases[:10])):
    visual_unique_countries.append(unique_countries[i])
    visual_confirmed_cases.append(country_confirmed_cases[i])
    
visual_unique_countries.append('Others')
visual_confirmed_cases.append(others)

# %%
def plot_bar_graphs(x, y, title):
    plt.figure(figsize=(16, 9))
    plt.barh(x, y)
    plt.title(title, size=20)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.show()

# %%
plot_bar_graphs(visual_unique_countries, visual_confirmed_cases, '# of Covid-19 Confirmed Cases in Countries/Regions')

# %%
def plot_pie_charts(x, y, title):
    c = random.choices(list(mcolors.CSS4_COLORS.values()),k = len(unique_countries))
    plt.figure(figsize=(20,15))
    plt.title(title, size=20)
    plt.pie(y, colors=c)
    plt.legend(x, loc='best', fontsize=15)
    plt.show()

# %%
plot_pie_charts(visual_unique_countries, visual_confirmed_cases, 'Covid-19 Confirmed Cases per Country')

# %%
# Plotting countries with regional data using a pie chart 

def plot_pie_country_with_regions(country_name, title):
    regions = list(latest_data[latest_data['Country_Region']==country_name]['Province_State'].unique())
    confirmed_cases = []
    no_cases = [] 
    for i in regions:
        cases = latest_data[latest_data['Province_State']==i]['Confirmed'].sum()
        if cases > 0:
            confirmed_cases.append(cases)
        else:
            no_cases.append(i)

    # remove areas with no confirmed cases
    for i in no_cases:
        regions.remove(i)

    # only show the top 10 states
    regions = [k for k, v in sorted(zip(regions, confirmed_cases), key=operator.itemgetter(1), reverse=True)]

    for i in range(len(regions)):
        confirmed_cases[i] = latest_data[latest_data['Province_State']==regions[i]]['Confirmed'].sum()  
    
    # additional province/state will be considered "others"
    
    if(len(regions)>10):
        regions_10 = regions[:10]
        regions_10.append('Others')
        confirmed_cases_10 = confirmed_cases[:10]
        confirmed_cases_10.append(np.sum(confirmed_cases[10:]))
        plot_pie_charts(regions_10,confirmed_cases_10, title)
    else:
        plot_pie_charts(regions,confirmed_cases, title)

# %%
plot_pie_country_with_regions('US', 'COVID-19 Confirmed Cases in the United States')
